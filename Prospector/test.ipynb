# %%
from pettingzoo.butterfly import prospector_v4
import numpy as np
from array2gif import write_gif
import os
os.environ["SDL_VIDEODRIVER"] = "dummy"
import matplotlib.pyplot as plt

# %%
env = prospector_v4.env(ind_reward=0.8, group_reward=0.1, other_group_reward=0.1,
prospec_find_gold_reward=1, prospec_handoff_gold_reward=1, banker_receive_gold_reward=1,banker_deposit_gold_reward=1, max_cycles=150)

# %%
env.reset()
plt.imshow(env.render(mode='rgb_array'))
plt.show()
